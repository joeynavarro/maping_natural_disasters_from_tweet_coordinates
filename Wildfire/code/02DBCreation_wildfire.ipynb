# %% [markdown]
# **This notebook assigns coordinates to wildfire twitter posts(because twitter block this info for most posts)**
#
# This code is adapted from group member Juhee Sung-Schenck

# %%
# import libraries

import pandas as pd
import numpy as np
import math
from numpy import random

import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
df1 = pd.read_csv('../data/wildfire_new.csv')
df2 = pd.read_csv('../data/no_wildfire_new.csv')

# %%
# read in the data

eq = pd.concat([df1,df2])

# %%
df1.date.min()
# Out:
# '2019-09-18 10:21:27+00:00'

# %%
df2.date.min()
# Out:
# '2020-01-09 23:59:35+00:00'

# %%
eq.reset_index(drop=True, inplace=True)
eq.shape
# Out:
# (20000, 6)

# %%
# check for null values - geocode not available for all tweets

eq.isnull().sum()
# Out:
# id               0
# text             1
# keyword      17267
# user_name        0
# date             0
# location     20000
# dtype: int64

# %%
# create a function to generate coordinates within given radius
# this code is my adaptation of Haversine formula
# Bob's genius brain has been input here

def get_coordinates(num, center, radius):
        
    lat, long = center
    
    # add randomness to generate latitude and longitude within the given radius
    rho = np.sqrt(np.random.uniform(0, 1, num))
    phi = np.random.uniform(0, 2 * np.pi, num)
    
    dx = rho * radius * np.cos(phi)
    dy = rho * radius * np.sin(phi)

    # create an empty list to store generated coordinates 
    coordinates = []
    
    for i in range(num):
        
        coordinate = {}
        
        # earth's mean radius is 6371 km
        new_lat = lat + ((180 / math.pi) * (dy[i] / 6371) / math.sin(lat * math.pi / 180)) 
        new_long = long + ((180 / math.pi) * (dx[i] / 6371) / math.cos(long * math.pi / 180))
        
        coordinate['lat'] = new_lat
        coordinate['long'] = new_long
        
        # add to list
        coordinates.append(coordinate)

    return coordinates

# %%
coordinates = get_coordinates(len(eq['location']), (36.7378, -119.7871), 150) # --> radius of collected tweets from the center

# %%
# create columns to store latitude and longitude separately

eq['lat'] = [coordinate['lat'] for coordinate in coordinates]
eq['long'] = [coordinate['long'] for coordinate in coordinates]

# %%
eq.head()
# Out:
#                     id                                               text  \
# 0  1305657570774978560  Smoke from California wildfires causes hazy sk...
# 1  1304359517552095235  96% Overwhelmingly Positive Reviews! Grab a fr...
# 2  1305657551703412736  So a 2-3 degree temperature difference is what...
# 3  1305657540227850240  @POTUS is right about the #wildfires Expert in...
# 4  1305657538281533440  Wildfires in California ARE caused by poor lan...
#
#               keyword        user_name                       date  location  \
# 0                 NaN  FireandAviation  2020-09-14 23:59:57+00:00       NaN
# 1                 NaN     JoinDeepRock  2020-09-11 10:01:57+00:00       NaN
# 2                 NaN   matthew_paul17  2020-09-14 23:59:52+00:00       NaN
# 3  #wildfires #global    Josie95450522  2020-09-14 23:59:50+00:00       NaN
# 4                 NaN           Arqahn  2020-09-14 23:59:49+00:00       NaN
#
#          lat        long
# 0  37.280386 -122.128109
# 1  36.052556 -119.406770
# 2  35.839572 -122.243498
# 3  34.897778 -119.722077
# 4  38.370841 -120.107434

# %%
# check the coordinates

fig = px.scatter_mapbox(eq, lat = 'lat', lon = 'long',
                        color_discrete_sequence = ['navy'], zoom = 1, height = 500)
fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(margin = {'r': 0, 't': 0, 'l': 0, 'b':0})

fig.write_html('../images/test-fig2.html')
fig.show()
# Out:
# <div>
#
#
#             <div id="6b82093f-5d32-476d-84ad-473012b8322a" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b82093f-5d32-476d-84ad-473012b8322a")) {
#                     Plotly.newPlot(
#                         '6b82093f-5d32-476d-84ad-473012b8322a',
#                         [{"hovertemplate": "lat=%{lat}<br>long=%{lon}<extra></extra>", "lat": [37.280386275516534, 36.05255580527329, 35.83957238720594, 34.89777762116503, 38.37084092056495, 36.99092452561613, 36.97547521949094, 35.496631129102695, 36.217826586637514, 36.45135948066344, 36.379227577880194, 35.67781343701407, 35.38017990183681, 37.55353942406964, 37.31444131752918, 36.263094177407524, 35.34902364685191, 38.41715031374544, 36.92161126312544, 36.30660936886511, 37.3962433176842, 37.97453270057851, 37.98159903790361, 35.45406003734376, 36.28180831225195, 37.37411239851385, 37.47601803693608, 36.86366341176781, 35.84653417607208, 35.19758872953497, 37.74920411344235, 35.301825193141326, 35.97935642446428, 36.80074370716733, 38.66197921013029, 38.58538928283994, 38.212672755909274, 35.407636871046705, 37.23391980091942, 36.13440418700494, 35.049637707048916, 37.222284322587974, 36.79771102673395, 37.99965334179767, 35.9102991716331, 36.25167214985281, 35.53588304208352, 37.167220988040434, 37.38677471022007, 35.87713567723887, 36.68823108031862, 37.76306410589319, 37.352747095095665, 38.43410067846132, 36.264309190153455, 35.23207151292857, 36.591984778969284, 35.68970063489139, 34.62105698942028, 35.19948611546704, 36.27807322146649, 38.620886903308794, 38.60704587888458, 35.72566417125632, 36.258689099509546, 36.715262047720515, 37.145242026844905, 36.0803080882598, 37.72372261859415, 38.46239532088442, 35.02661170710824, 37.29901361843617, 37.60207947020349, 35.51352325744848, 35.57505859677369, 37.27966222663403, 38.81149473849799, 35.79961194610822, 37.139856423364016, 36.23835434136371, 35.90830120758759, 35.79211658035135, 34.82553355876959, 35.96687313882997, 35.970652666242344, 34.7683187794884, 34.92584394719903, 35.64930122215805, 36.804456623129305, 37.52417154420132, 36.93149559502894, 35.54492912268595, 35.907579772358794, 36.79800907769148, 36.359039537654255, 35.353387923388006, 36.32117368996639, 35.01802867666587, 34.93927341931503, 37.19493564940121, 37.50385716736824, 38.504342655224946, 36.9087151450199, 36.94277181110805, 34.979102538966494, 37.083285865304255, 37.76095469690424, 35.5814727214898, 35.793958371519395, 35.97087344064252, 37.68891684877282, 38.68612728172304, 36.644431551476764, 36.531935743890344, 36.375937787587425, 36.136078490850146, 34.826464684260806, 36.6931411354465, 37.60997589566711, 37.62798123709507, 35.56867951306778, 37.95234585944293, 36.374843935755635, 36.856403893468716, 37.67760454916783, 38.7903827986342, 35.03799816046451, 38.112552349464764, 36.529384965450475, 35.44865241367456, 35.34891579989893, 38.87990550733692, 38.23590343545228, 36.24958257441479, 35.40252441734024, 35.90043390990534, 37.074838261433946, 35.54029790680645, 36.64677184565355, 35.75095061486718, 34.77532428425861, 36.15329920302823, 37.832403912759325, 36.661026996942724, 37.06516843683313, 36.373447218739216, 35.29473981431968, 35.71452217082088, 36.459344795961684, 35.54878106285376, 35.75574820870101, 38.545572716993654, 35.835134991979984, 38.298535107141, 37.21877173893029, 36.50122007773843, 35.5688749485391, 37.90957130248201, 37.282023071809924, 37.78050358684262, 36.41472850160955, 36.52900651074137, 36.51091989354764, 36.03590995618957, 35.97352434378344, 36.47582310232065, 38.402092908489884, 35.99386764199919, 38.17857888322514, 38.18672684361999, 37.83099549980932, 37.27345750097017, 37.28697642340945, 34.80597625084363, 35.03847913240817, 35.06892648646116, 36.885545938697774, 36.34410865863993, 36.239854423771945, 35.39838742953404, 36.06562836619328, 36.47798529162863, 34.69668060960326, 36.88054985919608, 36.495937068190386, 35.38555733552227, 37.34771725201397, 37.92931298052975, 37.44786898552589, 35.5654640323686, 35.28427767258808, 36.487972146604356, 36.35896804313496, 36.3078474683099, 38.355249079353975, 36.85228884892327, 35.72204058078117, 37.570627063359495, 37.377933136983195, 35.5389071543482, 36.58323623689073, 37.559226766338305, 35.26729656251534, 37.42785 ...

# %%
eq.drop(columns=['keyword', 'location']).to_csv('../data/final.csv', index=False)
